# %%
*import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')
# %matplotlib inline
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# First we will load the data and understand its dimension *

# reading the data from the csv file
data_BPD = pd.read_csv('BPD_Arrests.csv')
data_BPD.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Arrest   Age Sex Race  ArrestDate ArrestTime     ArrestLocation  \
# 0  19094707.0  35.0   M    W  06/30/2019      12:50                NaN
# 1  19094731.0  31.0   M    B  06/30/2019      17:00                NaN
# 2  19094781.0  26.0   M    B  06/30/2019      23:50                NaN
# 3  19094789.0  26.0   M    B  06/30/2019      21:52                NaN
# 4  19094698.0  20.0   M    B  06/30/2019      10:02        800 22ND ST
# 5  19094712.0  37.0   M    B  06/30/2019      10:04    1900 FEDERAL ST
# 6  19094689.0  27.0   F    B  06/30/2019      05:18  4900 CHALLEDON RD
# 7  19094696.0  33.0   M    W  06/30/2019      10:50                NaN
# 8  19094765.0  29.0   F    W  06/30/2019      21:10                NaN
# 9  19094666.0  23.0   F    B  06/30/2019      04:30    1500 RUSSELL ST
#
#        IncidentOffense   IncidentLocation  Charge   ChargeDescription  \
# 0      Unknown Offense                NaN  1 0077   FAILURE TO APPEAR
# 1      Unknown Offense                NaN  1 0077   FAILURE TO APPEAR
# 2     4ECOMMON ASSAULT                NaN  1 1415  ASSAULT-SEC DEGREE
# 3      Unknown Offense                NaN  1 0077   FAILURE TO APPEAR
# 4     4ECOMMON ASSAULT        800 22ND ST  1 1415             ASSAULT
# 5  4DAGG. ASSLT.- HAND    1900 FEDERAL ST  1 1415             ASSAULT
# 6      Unknown Offense  4900 CHALLEDON RD  1 1415             ASSAULT
# 7  3BROBB HIGHWAY (UA)                NaN  2 0700             ROBBERY
# 8      Unknown Offense                NaN     NaN         DETAIN ONLY
# 9  4CAGG. ASSLT.- OTH.    1500 RUSSELL ST  1 1415      COMMON ASSAULT
#
#     District Post  Neighborhood        Longitude Latitude  Location 1
# 0        NaN  NaN           NaN              NaN      NaN         NaN
# 1        NaN  NaN           NaN              NaN      NaN         NaN
# 2        NaN  NaN           NaN              NaN      NaN         NaN
# 3        NaN  NaN           NaN              NaN      NaN         NaN
# 4    Eastern  312           NaN  -76.60656500000  39.3147         NaN
# 5    Eastern  331           NaN  -76.59103456076  39.3087         NaN
# 6  Southwest  821           NaN  -76.69910002406  39.3125         NaN
# 7        NaN  NaN           NaN              NaN      NaN         NaN
# 8        NaN  NaN           NaN              NaN      NaN         NaN
# 9   Southern  941           NaN  -76.62769512055  39.2741         NaN

# %% [markdown]
# # META DATA
# ##### Arrest-ID
# ##### Age
# ##### Sex
# ##### Race
# ##### ArrestDate
# ##### ArrestTime
# ##### ArrestLocation
# ##### IncidentOffense
# ##### IncidentLocation
# ##### Charge
# ##### ChargeDescription
# ##### District
# ##### Post
# ##### Neighborhood
# ##### Location1(Location Coordinates)

# %%
print(data_BPD.shape) # Get the shape of the data
#So the data have * 145654 * observations and * 15 * variables.
# Out:
# (145231, 17)

# %% [markdown]
# # So the data have * 145231 * observations and * 17 * variables.

# %%
data_BPD.describe(include='all').T #Generates descriptive statistics
# Out:
#                     count unique                top    freq         mean  \
# Arrest             138237    NaN                NaN     NaN  1.60794e+07
# Age                145191    NaN                NaN     NaN      32.9076
# Sex                145231      2                  M  117186          NaN
# Race               145231      5                  B  118798          NaN
# ArrestDate         145231   2007         01/09/2014     178          NaN
# ArrestTime         145231   1842              13:00    2387          NaN
# ArrestLocation      78487  16092    1500 RUSSELL ST     442          NaN
# IncidentOffense    145231    160    Unknown Offense   76823          NaN
# IncidentLocation    78487  16092    1500 RUSSELL ST     442          NaN
# Charge             128656    616             1 1415   24449          NaN
# ChargeDescription  145231   6435  FAILURE TO APPEAR   22656          NaN
# District            79013     56           Southern   10135          NaN
# Post                77668    141                331    2300          NaN
# Neighborhood            0    NaN                NaN     NaN          NaN
# Longitude           77208  25297   -76.627695120552     387          NaN
# Latitude            77208  30180    39.274088468453     210          NaN
# Location 1              0    NaN                NaN     NaN          NaN
#
#                            std      min          25%          50%  \
# Arrest             1.62554e+06  1.4e+07  1.42034e+07  1.60601e+07
# Age                    11.4373       14           24           30
# Sex                        NaN      NaN          NaN          NaN
# Race                       NaN      NaN          NaN          NaN
# ArrestDate                 NaN      NaN          NaN          NaN
# ArrestTime                 NaN      NaN          NaN          NaN
# ArrestLocation             NaN      NaN          NaN          NaN
# IncidentOffense            NaN      NaN          NaN          NaN
# IncidentLocation           NaN      NaN          NaN          NaN
# Charge                     NaN      NaN          NaN          NaN
# ChargeDescription          NaN      NaN          NaN          NaN
# District                   NaN      NaN          NaN          NaN
# Post                       NaN      NaN          NaN          NaN
# Neighborhood               NaN      NaN          NaN          NaN
# Longitude                  NaN      NaN          NaN          NaN
# Latitude                   NaN      NaN          NaN          NaN
# Location 1                 NaN      NaN          NaN          NaN
#
#                            75%          max
# Arrest             1.71729e+07  1.90948e+07
# Age                         40          100
# Sex                        NaN          NaN
# Race                       NaN          NaN
# ArrestDate                 NaN          NaN
# ArrestTime                 NaN          NaN
# ArrestLocation             NaN          NaN
# IncidentOffense            NaN          NaN
# IncidentLocation           NaN          NaN
# Charge                     NaN          NaN
# ChargeDescription          NaN          NaN
# District                   NaN          NaN
# Post                       NaN          NaN
# Neighborhood               NaN          NaN
# Longitude                  NaN          NaN
# Latitude                   NaN          NaN
# Location 1                 NaN          NaN

# %%
# Let’s see how many missing values we have in each variable
for column in data_BPD.columns:
    print(column, data_BPD[column].isnull().sum())
# Out:
# Arrest 6994
# Age 40
# Sex 0
# Race 0
# ArrestDate 0
# ArrestTime 0
# ArrestLocation 66744
# IncidentOffense 0
# IncidentLocation 66744
# Charge 16575
# ChargeDescription 0
# District 66218
# Post 67563
# Neighborhood 145231
# Longitude 68023
# Latitude 68023
# Location 1 145231

# %% [markdown]
# We have NA values and missing labels in some variables.
#
# This is quite intuitive in real world data.
#
# We have to prepare our data taking care of all hindrances.

# %%
#Lets’ understand the Age distribution:

plt.figure(figsize = (12,8)) # set the figure size
plt.xlabel('Age', fontsize=18) # set the label of the x axis
plt.ylabel('Count', fontsize=18) # set the label of the y axis
data_BPD['Age'].hist(bins = 50, color= '#2E2E2E') # plotting

# %%
#As we see most of arrests are in the age group of * 20 -27. *

# %%
#A cursory view of gender (Sex) distribution reveals the following:
plt.figure(figsize = (12,8))
plt.ylabel('Sex', fontsize=18)
plt.ylabel('count', fontsize=18)
data_BPD['Sex'].value_counts().plot.bar(stacked=True, color='#2A0A29')

# %%
#So the number of arrests is dominated by * male *.

# %%
# Let’s see how the race is distributed: 

plt.figure(figsize = (12,8))
plt.xlabel('Race', fontsize=18)
plt.ylabel('count', fontsize=18)

data_BPD['Race'].value_counts().plot.bar(stacked=True, color='#071418')

# %%
#So, we see from data people from B Race group are mostly arrested by police.

# %%
##We have variables recording the * Arrest Date * and * Arrest Time *. We can use these variables to reveal some interesting patterns.

#First let's convert our ArrestDate and ArrestTime columns to pandas.datetime type:
data_BPD['ArrestDate'] = pd.to_datetime(data_BPD['ArrestDate'], format='%m/%d/%Y')

# Some of the observations have hh.mm format so we adjust them to have the same format as the other observations hh:mm
data_BPD['ArrestTime'] = data_BPD['ArrestTime'].map(lambda s: s.replace('.', ':'))
data_BPD['ArrestTime'] = pd.to_datetime(data_BPD['ArrestTime'], format='%H:%M')

plt.figure(figsize = (12,8))
(data_BPD['ArrestDate']
.groupby(data_BPD.ArrestDate.dt.weekday_name) # first we group our data by the day of the week
.agg('count') # We then compute the number of observation we have in each group
.plot.bar(stacked=True, color='#0A2A0A') # Plotting
)
plt.xlabel('Weekday of arrest', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
#We can see that * weekends * have fewer number of arrests.

# %%
plt.figure(figsize = (12,8))
(data_BPD['ArrestDate']
.groupby(data_BPD.ArrestDate.dt.month)
.agg('count')
.plot.bar(stacked=True, color='#0A2229')
)
plt.xlabel('Month of arrest', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize = (12,8))
(data_BPD['ArrestDate']
.groupby(data_BPD.ArrestDate.dt.year)
.agg('count')
.plot.bar(stacked=True, color='#220A29')
)
plt.xlabel('Year of arrest', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
#Number of people arrested also show a * declining trend* year-on-year (2013-2017).

# %%
plt.figure(figsize = (12,8))
(data_BPD['ArrestDate']
.groupby(data_BPD.ArrestTime.dt.hour)
.agg('count')
.plot.bar(stacked=True, color='#610B0B')
)
plt.xlabel('Hour of arrest', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
#Now, we can see when most of the arrests occur in the * day*. There are fewer arrests in early morning.

# %%
#Top 15 arrest locations are the following:
data_BPD['ArrestLocation'].value_counts()[:15].to_frame('Number of arrests')
# Out:
#                        Number of arrests
# 1500 RUSSELL ST                      442
# 1600 NORTH AVE                       312
# 200 EUTAW ST                         284
# 400 BALTIMORE ST                     237
# 1800 PENNSYLVANIA AVE                227
# 600 LAURENS ST                       220
# 5100 REISTERSTOWN RD                 211
# 400 SARATOGA ST                      209
# 400 LEXINGTON ST                     209
# 2400 FREDERICK AVE                   209
# 1500 NORTH AVE                       207
# 1800 PRATT ST                        186
# 300 EUTAW ST                         179
# 2400 PENNSYLVANIA AVE                174
# 5100 PARK HEIGHTS AVE                158

# %%
#Top 15 Incident Offense are the following:
import re

# We remove symbols from IncidentOffense column and convert it to lowercase
data_BPD['IncidentOffense'] = data_BPD['IncidentOffense'].map(lambda s : re.sub('[^\w]','', s).lower())

data_BPD['IncidentOffense'].value_counts()[:15].to_frame('Number of incidents')
# Out:
#                       Number of incidents
# unknownoffense                      76823
# 87narcotics                         20366
# 4ecommonassault                      8878
# 97searchseizure                      3283
# 54armedperson                        2776
# 4caggassltoth                        2483
# 87onarcoticsoutside                  2476
# 6clarcenyshoplifting                 2248
# 4baggassltcut                        1942
# 24towedvehicle                       1777
# 79other                              1707
# 5aburgresforce                       1234
# 7astolenauto                         1073
# 115trespassing                       1025
# 55disorderlyperson                   1011

# %%
#Top 15 Incident Locations are the following:

# %%
data_BPD['IncidentLocation'].value_counts()[:15].to_frame('Number of incidents')
# Out:
#                        Number of incidents
# 1500 RUSSELL ST                        442
# 1600 NORTH AVE                         312
# 200 EUTAW ST                           284
# 400 BALTIMORE ST                       237
# 1800 PENNSYLVANIA AVE                  227
# 600 LAURENS ST                         220
# 5100 REISTERSTOWN RD                   211
# 2400 FREDERICK AVE                     209
# 400 LEXINGTON ST                       209
# 400 SARATOGA ST                        209
# 1500 NORTH AVE                         207
# 1800 PRATT ST                          186
# 300 EUTAW ST                           179
# 2400 PENNSYLVANIA AVE                  174
# 5100 PARK HEIGHTS AVE                  158

# %%
#Top 15 charges: 

data_BPD['ChargeDescription'].value_counts()[:15].to_frame('Number of arrests')
# Out:
#                         Number of arrests
# FAILURE TO APPEAR                   22656
# ASSAULT-SEC DEGREE                  11843
# CDS VIOLATION                       10588
# CDS                                  9550
# Unknown Charge                       7636
# VIOLATION OF PROBATION               4076
# COMMON ASSAULT                       4067
# HGV                                  2815
# ASSAULT                              2560
# ASSAULT-FIRST DEGREE                 2274
# DETAIN ONLY                          1880
# ARMED ROBBERY                        1746
# LARCENY                              1660
# PROSTITUTION                         1583
# STOLEN AUTO                          1582

# %%
#Lets’ view the distribution of people arrested across different districts: 

plt.figure(figsize = (12,8))
data_BPD['District'].value_counts().plot.bar(stacked=True, color='#2A0A29')
plt.xlabel('District', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('District Distribution', fontsize=20)
# Out:
# Text(0.5, 1.0, 'District Distribution')

# %%
#Comparatively, * Southern district * has more number of arrests.

# %%
##Distribution of Arrest Year & Arrest month
data_BPD['year'] = data_BPD['ArrestDate'].dt.year
data_BPD['month'] = data_BPD['ArrestDate'].dt.month
(data_BPD.pivot_table('Arrest', index='year', columns='month', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)

plt.xlabel('Year', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Distribution of Arrest Year and Arrest month', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Distribution of Arrest Year and Arrest month')

# %%
hour_period_map = {
0 : '0-3',
1 : '0-3',
2 : '0-3',
3 : '0-3',
4 : '4-7',
5 : '4-7',
6 : '4-7',
7 : '4-7',
8 : '8-11',
9 : '8-11',
10 : '8-11',
11 : '8-11',
12 : '12-15',
13 : '12-15',
14 : '12-15',
15 : '12-15',
16 : '16-19',
17 : '16-19',
18 : '16-19',
19 : '16-19',
20 : '20-23',
21 : '20-23',
22 : '20-23',
23 : '20-23',
}
data_BPD['period_in_day'] = data_BPD['ArrestTime'].map(lambda time : hour_period_map[time.hour])
data_BPD['weekday'] = data_BPD['ArrestDate'].dt.weekday_name
(data_BPD.pivot_table('Arrest', index='weekday', columns='period_in_day', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)

plt.xlabel('Day in the week', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Distribution of arrests Weekdays and Time', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Distribution of arrests Weekdays and Time')

# %%
def age_cat_map(age):
  
 if age < 20 :
    return '0-20'
 elif age < 40 :
    return '20-40'
 elif age < 60 :
    return '40-60'
 elif age < 60 :
    return '60-80'
 else :
    return '80-'

data_BPD['age_cat'] = data_BPD['Age'].map(age_cat_map)
(data_BPD.pivot_table('Arrest', index='Sex', columns='age_cat', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)
plt.title('Distribution of Arrests Age & Sex', fontsize = 22)
plt.xlabel('Sex', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
(data_BPD.pivot_table('Arrest', index='Race', columns='age_cat', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)

plt.xlabel('Race', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Distribution of Arrests Age & Race', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Distribution of Arrests Age & Race')

# %%
(data_BPD.pivot_table('Arrest', index='year', columns='Sex', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)
plt.title('Distribution of Arrests Year & Sex', fontsize = 22)
plt.xlabel('Year', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
(data_BPD.pivot_table('Arrest', index='year', columns='Race', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)
plt.title('Distribution of Arrests Year & Race', fontsize = 22)

plt.xlabel('Year', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
(data_BPD.pivot_table('Arrest', index='year', columns='District', aggfunc = 'count', fill_value=0)
.plot(kind='bar',stacked=True, figsize=(18,10))
)
plt.title('Distribution of Arrests Year & District', fontsize = 22)

plt.xlabel('Year', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
(data_BPD.pivot_table('Arrest', index='Age', columns='Race', aggfunc = 'count', fill_value=0)
.plot(kind='bar', stacked = True, figsize=(18,10))
)
plt.title('Distribution of arrests age and race in a histogram', fontsize = 22)

plt.xlabel('Age', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
df = data_BPD.pivot_table('Arrest', index='Age', columns='Race', aggfunc = 'count', fill_value=0)
plt.figure(figsize=(18,10))
plt.plot(df['A'])
plt.plot(df['B'])
plt.plot(df['U'])
plt.plot(df['I'])
plt.plot(df['W'])

plt.xlabel('Age', fontsize=18)
plt.ylabel('count', fontsize=18)
# Out:
# Text(0, 0.5, 'count')

# %%
(data_BPD.pivot_table('Arrest', index='Age', columns='District', aggfunc = 'count', fill_value=0)
.plot(kind='bar', stacked = True, figsize=(18,10))
)

plt.xlabel('Age', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Arrests across district and age', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Arrests across district and age')

# %%
(data_BPD.pivot_table('Arrest', index='Age', columns='month', aggfunc = 'count', fill_value=0)
.plot(kind='bar', stacked = True, figsize=(18,10))
)

plt.xlabel('Age', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Arrests Age Month', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Arrests Age Month')

# %%
(data_BPD.pivot_table('Arrest', index='Age', columns='year', aggfunc = 'count', fill_value=0)
.plot(kind='bar', stacked = True, figsize=(18,10))
)

plt.xlabel('Age', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Arrests Age Year', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Arrests Age Year')

# %%
(data_BPD.pivot_table('Arrest', index='Age', columns='weekday', aggfunc = 'count', fill_value=0)
.plot(kind='bar', stacked = True, figsize=(18,10))
)

plt.xlabel('Age', fontsize=18)
plt.ylabel('count', fontsize=18)
plt.title('Distribution of Arrests on age and Weekdays', fontsize = 22)
# Out:
# Text(0.5, 1.0, 'Distribution of Arrests on age and Weekdays')

# %%
#We have seen the distributions of number of arrests across various variables and the interactions among them.
